# %% [markdown]
# ### Exersize 3a

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
Class_1_Points = np.array([[-1,1],[-1,-1]])
Class_2_Points = np.array([[1,-1],[1,1]])
plt.figure(figsize=(10,10))
plt.plot(Class_1_Points[:,0],Class_1_Points[:,1],'b*')
plt.plot(Class_2_Points[:,0],Class_2_Points[:,1],'yo')
plt.vlines(x=0, ymin=-1.5, ymax=1.5, colors='r', linestyles='--', lw=2)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()

# %% [markdown]
# The seperating hyperplane for the SVM solution is x1 = 0
